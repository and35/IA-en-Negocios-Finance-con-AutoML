# %% [markdown]
# #1: ENTENDER EL ENUNCIADO DEL PROBLEMA Y EL CASO PRÁCTICO

# %% [markdown]
# - En este caso de estudio, asumiremos que trabajamos como
# científico de datos en un banco en Taiwán.
# - El banco ha recopilado una gran cantidad de datos sobre sus
# clientes, como datos demográficos, historial de pagos, cantidad
# de valores en dólares.
# - Los datos se recopilaron entre abril y septiembre de 2005.
# - Los datos constan de 25 variables. ¡Exploremos estas variables
# en la siguiente diapositiva!
# - Fuente de datos: https://www.kaggle.com/uciml/default-of-credit-card-
# clients-dataset-
#
# el objetivo es entrenar una IA que prediga los clientes que no tienen la posibiliad de pagar el credito (que se endeude con el banco), ser aun problema de clasificacion

# %% [markdown]
# #2: IMPORTAR LIBRERÍAS Y DATASETS

# %%
https://colab.research.google.com/drive/1Fb93abENqRfStTuckeMqeOqIgvJPrLAk?usp=sharing
